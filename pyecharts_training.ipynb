# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# %%
from pyecharts.render import make_snapshot
from snapshot_selenium import snapshot
bar = (
    Bar()
    .add_xaxis(['衬衫','羊毛衫', "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis('商家',[5,20,36,10,75,90])
    .set_global_opts(title_opts={'text':'主标题','subtext':'副标题'})
      )
make_snapshot(snapshot,bar.render(),'商家.png')

# %%
from pyecharts.render import make_snapshot
from snapshot_selenium import snapshot
make_snapshot(snapshot,bar.render(),'bar.png')

# %%
def bar_chart():
    c = (
        Bar()
        .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
        .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
        .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
        .reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(position="right"))
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-测试渲染图片"))
    )
    return c

make_snapshot(snapshot, bar_chart().render(), "bar0.png")

# %%
from pyecharts.globals import ThemeType

# %%
bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    .add_yaxis("商家B", [15, 6, 45, 20, 35, 66])
    .set_global_opts(title_opts=opts.TitleOpts(title='a',subtitle='b'))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="eb1149e78b034f999534ec7726ed4a94" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_eb1149e78b034f999534ec7726ed4a94 = echarts.init(
#                     document.getElementById('eb1149e78b034f999534ec7726ed4a94'), 'light', {renderer: 'canvas'});
#                 var option_eb1149e78b034f999534ec7726ed4a94 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
# ...

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.render import make_snapshot
x_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data = [123, 153, 89, 107, 98, 23]

# %%
bar = (
    Bar()
    .add_xaxis(x_data)
    .add_yaxis('',y_data)
    .set_global_opts(title_opts=opts.TitleOpts(title='商家'))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="98592dc7729647b7885719958505d2bc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_98592dc7729647b7885719958505d2bc = echarts.init(
#                     document.getElementById('98592dc7729647b7885719958505d2bc'), 'white', {renderer: 'canvas'});
#                 var option_98592dc7729647b7885719958505d2bc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
line = (
        Line(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
        .add_xaxis(x_data)
        .add_yaxis('',y_data)
        .set_global_opts(title_opts=opts.TitleOpts(title='商家')))
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d7c85c932e4042e19f1d6970d3daf501" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d7c85c932e4042e19f1d6970d3daf501 = echarts.init(
#                     document.getElementById('d7c85c932e4042e19f1d6970d3daf501'), 'light', {renderer: 'canvas'});
#                 var option_d7c85c932e4042e19f1d6970d3daf501 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "symbolSize": 4,
# ...

# %%
import numpy as np
y_data = [[np.random.randint(100, 200) for i in range(10)] for item in x_data]
box = (
    Boxplot()
    .add_xaxis(x_data)
    .add_yaxis('',Boxplot.prepare_data(y_data)))
box.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3cc3e4e56770446598a94e1f42ac7c4e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3cc3e4e56770446598a94e1f42ac7c4e = echarts.init(
#                     document.getElementById('3cc3e4e56770446598a94e1f42ac7c4e'), 'white', {renderer: 'canvas'});
#                 var option_3cc3e4e56770446598a94e1f42ac7c4e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
y_data = [[np.random.randint(100, 200) for i in range(10)] for item in x_data]
scatter = (
        Scatter()
        .add_xaxis(x_data)
        .add_yaxis('',y_data)
        )

scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d11fe8fa7d7648b59bfe92478e0ab36a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d11fe8fa7d7648b59bfe92478e0ab36a = echarts.init(
#                     document.getElementById('d11fe8fa7d7648b59bfe92478e0ab36a'), 'white', {renderer: 'canvas'});
#                 var option_d11fe8fa7d7648b59bfe92478e0ab36a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
y_data = [[np.random.randint(100, 200) for i in range(10)] for item in x_data]
y_data
# Out:
# [[143, 116, 140, 106, 149, 125, 100, 106, 128, 184],
#  [184, 160, 120, 195, 179, 154, 167, 166, 141, 117],
#  [199, 143, 176, 137, 132, 190, 170, 120, 136, 134],
#  [126, 101, 165, 183, 171, 158, 135, 192, 134, 113],
#  [116, 136, 104, 108, 100, 147, 174, 176, 152, 166],
#  [151, 191, 117, 195, 179, 160, 117, 103, 187, 164]]

# %%
y_data = [123, 153, 89, 107, 98, 23]
scatter = (
    EffectScatter()
    .add_xaxis(x_data)
    .add_yaxis('',y_data)
    .set_global_opts(title_opts=opts.TitleOpts(title='s'))
        )

scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4c2ccbb6051641259101b56d39175236" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4c2ccbb6051641259101b56d39175236 = echarts.init(
#                     document.getElementById('4c2ccbb6051641259101b56d39175236'), 'white', {renderer: 'canvas'});
#                 var option_4c2ccbb6051641259101b56d39175236 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
date_list = ['2021/4/{}'.format(i + 1) for i in range(30)]
date_list
# Out:
# ['2021/4/1',
#  '2021/4/2',
#  '2021/4/3',
#  '2021/4/4',
#  '2021/4/5',
#  '2021/4/6',
#  '2021/4/7',
#  '2021/4/8',
#  '2021/4/9',
#  '2021/4/10',
#  '2021/4/11',
#  '2021/4/12',
#  '2021/4/13',
#  '2021/4/14',
#  '2021/4/15',
#  '2021/4/16',
#  '2021/4/17',
#  '2021/4/18',
#  '2021/4/19',
#  '2021/4/20',
#  '2021/4/21',
#  '2021/4/22',
#  '2021/4/23',
#  '2021/4/24',
#  '2021/4/25',
#  '2021/4/26',
#  '2021/4/27',
#  '2021/4/28',
#  '2021/4/29',
#  '2021/4/30']

# %%
y_data = [
    [2320.26, 2320.26, 2287.3, 2362.94],
    [2300, 2291.3, 2288.26, 2308.38],
    [2295.35, 2346.5, 2295.35, 2345.92],
    [2347.22, 2358.98, 2337.35, 2363.8],
    [2360.75, 2382.48, 2347.89, 2383.76],
    [2383.43, 2385.42, 2371.23, 2391.82],
    [2377.41, 2419.02, 2369.57, 2421.15],
    [2425.92, 2428.15, 2417.58, 2440.38],
    [2411, 2433.13, 2403.3, 2437.42],
    [2432.68, 2334.48, 2427.7, 2441.73],
    [2430.69, 2418.53, 2394.22, 2433.89],
    [2416.62, 2432.4, 2414.4, 2443.03],
    [2441.91, 2421.56, 2418.43, 2444.8],
    [2420.26, 2382.91, 2373.53, 2427.07],
    [2383.49, 2397.18, 2370.61, 2397.94],
    [2378.82, 2325.95, 2309.17, 2378.82],
    [2322.94, 2314.16, 2308.76, 2330.88],
    [2320.62, 2325.82, 2315.01, 2338.78],
    [2313.74, 2293.34, 2289.89, 2340.71],
    [2297.77, 2313.22, 2292.03, 2324.63],
    [2322.32, 2365.59, 2308.92, 2366.16],
    [2364.54, 2359.51, 2330.86, 2369.65],
    [2332.08, 2273.4, 2259.25, 2333.54],
    [2274.81, 2326.31, 2270.1, 2328.14],
    [2333.61, 2347.18, 2321.6, 2351.44],
    [2340.44, 2324.29, 2304.27, 2352.02],
    [2326.42, 2318.61, 2314.59, 2333.67],
    [2314.68, 2310.59, 2296.58, 2320.96],
    [2309.16, 2286.6, 2264.83, 2333.29],
    [2282.17, 2263.97, 2253.25, 2286.33],
]

kline = (
        Kline()
        .add_xaxis(date_list)
        .add_yaxis('',y_data))
kline.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3d01dfd20c374a0fab3b4d8283161a8d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3d01dfd20c374a0fab3b4d8283161a8d = echarts.init(
#                     document.getElementById('3d01dfd20c374a0fab3b4d8283161a8d'), 'white', {renderer: 'canvas'});
#                 var option_3d01dfd20c374a0fab3b4d8283161a8d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
data = [[i, j, np.random.randint(0, 100)] for i in range(24) for j in range(7)]
data
# Out:
# [[0, 0, 17],
#  [0, 1, 32],
#  [0, 2, 89],
#  [0, 3, 95],
#  [0, 4, 23],
#  [0, 5, 99],
#  [0, 6, 26],
#  [1, 0, 53],
#  [1, 1, 24],
#  [1, 2, 35],
#  [1, 3, 12],
#  [1, 4, 13],
#  [1, 5, 1],
#  [1, 6, 12],
#  [2, 0, 11],
#  [2, 1, 52],
#  [2, 2, 21],
#  [2, 3, 85],
#  [2, 4, 96],
#  [2, 5, 59],
#  [2, 6, 0],
#  [3, 0, 46],
#  [3, 1, 12],
#  [3, 2, 91],
#  [3, 3, 53],
#  [3, 4, 27],
#  [3, 5, 68],
#  [3, 6, 59],
#  [4, 0, 44],
#  [4, 1, 34],
#  [4, 2, 42],
#  [4, 3, 26],
#  [4, 4, 76],
#  [4, 5, 9],
#  [4, 6, 14],
#  [5, 0, 23],
#  [5, 1, 67],
#  [5, 2, 51],
#  [5, 3, 95],
#  [5, 4, 17],
#  [5, 5, 69],
#  [5, 6, 91],
#  [6, 0, 23],
#  [6, 1, 38],
#  [6, 2, 13],
#  [6, 3, 54],
#  [6, 4, 38],
#  [6, 5, 44],
#  [6, 6, 66],
#  [7, 0, 11],
#  [7, 1, 78],
#  [7, 2, 4],
#  [7, 3, 0],
#  [7, 4, 32],
#  [7, 5, 6],
#  [7, 6, 58],
#  [8, 0, 3],
#  [8, 1, 92],
#  [8, 2, 57],
#  [8, 3, 46],
#  [8, 4, 59],
#  [8, 5, 63],
#  [8, 6, 64],
#  [9, 0, 58],
#  [9, 1, 22],
#  [9, 2, 49],
#  [9, 3, 77],
# ...

# %%
hour_list = [str(i) for i in range(24)]
week_list = ['周日', '周一', '周二', '周三', '周四', '周五', '周六']
heat = (HeatMap()
       .add_xaxis(hour_list)
       .add_yaxis("", week_list, data))
heat.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="713b44e44a1f40b1a2a593691c1f627f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_713b44e44a1f40b1a2a593691c1f627f = echarts.init(
#                     document.getElementById('713b44e44a1f40b1a2a593691c1f627f'), 'white', {renderer: 'canvas'});
#                 var option_713b44e44a1f40b1a2a593691c1f627f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data = [123, 153, 89, 107, 98, 23]
pictorial_bar = (
                PictorialBar()
                .add_xaxis(x_data)
                .add_yaxis('', y_data)
                )
pictorial_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="04681e076a004a3fbd68d22ca5cf2551" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_04681e076a004a3fbd68d22ca5cf2551 = echarts.init(
#                     document.getElementById('04681e076a004a3fbd68d22ca5cf2551'), 'white', {renderer: 'canvas'});
#                 var option_04681e076a004a3fbd68d22ca5cf2551 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data_bar = [123, 153, 89, 107, 98, 23]
y_data_line = [153, 107, 23, 89, 123, 107]


bar = (Bar()
       .add_xaxis(x_data)
       .add_yaxis('', y_data_bar)
       )

line = (Line()
        .add_xaxis(x_data)
        .add_yaxis('', y_data_line)
        )

overlap = bar.overlap(line)
overlap.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="006ff771506644fcab6c0c5cdc1101c9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_006ff771506644fcab6c0c5cdc1101c9 = echarts.init(
#                     document.getElementById('006ff771506644fcab6c0c5cdc1101c9'), 'white', {renderer: 'canvas'});
#                 var option_006ff771506644fcab6c0c5cdc1101c9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# # 地理图表

# %%
# province = [
#     '广东',
#     '湖北',
#     '湖南',
#     '四川',
#     '重庆',
#     '黑龙江',
#     '浙江',
#     '山西',
#     '河北',
#     '安徽',
#     '河南',
#     '山东',
#     '西藏']
# data = [(i, np.random.randint(50, 150)) for i in province]
data = (['广东',11],
        ['北京',23])

# %%
province = [
    '广东',
    '湖北',
    '湖南',
    '四川',
    '重庆',
    '黑龙江',
    '浙江',
    '山西',
    '河北',
    '安徽',
    '河南',
    '山东',
    '西藏']
data = [(i, np.random.randint(50, 150)) for i in province]

geo = (
    Geo()
    .add_schema(maptype="china")
    .add("", data)
)
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="91fef26f3708458ba8057721cd96fca0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_91fef26f3708458ba8057721cd96fca0 = echarts.init(
#                     document.getElementById('91fef26f3708458ba8057721cd96fca0'), 'white', {renderer: 'canvas'});
#                 var option_91fef26f3708458ba8057721cd96fca0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
province = [
    '广东',
    '湖北',
    '湖南',
    '四川',
    '重庆',
    '黑龙江',
    '浙江',
    '山西',
    '河北',
    '安徽',
    '河南',
    '山东',
    '西藏']
data = [(i, np.random.randint(50, 150)) for i in province]

map = (
    Map()
    .add('',data,'china'))

map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="4dcf138ca2e74cd2ac5b6bc8643ce3c0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_4dcf138ca2e74cd2ac5b6bc8643ce3c0 = echarts.init(
#                     document.getElementById('4dcf138ca2e74cd2ac5b6bc8643ce3c0'), 'white', {renderer: 'canvas'});
#                 var option_4dcf138ca2e74cd2ac5b6bc8643ce3c0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
province = [
    '广东',
    '湖北',
    '湖南',
    '四川',
    '重庆',
    '黑龙江',
    '浙江',
    '山西',
    '河北',
    '安徽',
    '河南',
    '山东',
    '西藏']
data = [(i, np.random.randint(50, 150)) for i in province]

bmap = (
    BMap()
    .add_schema(baidu_ak='FAKE_AK', center=[120.13066322374, 30.240018034923])
    .add('',data))

bmap.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'bmap':'https://assets.pyecharts.org/assets/bmap.min', 'baidu_map_api46':'https://api.map.baidu.com/api?v=2.0&ak=FAKE_AK', 'baidu_map_api52':'https://api.map.baidu.com/getscript?v=2.0&ak=FAKE_AK'
#         }
#     });
# </script>
#
#         <div id="85500dfca10f47a6b309912d6d9433f8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'bmap', 'baidu_map_api46', 'baidu_map_api52'], function(echarts) {
#                 var chart_85500dfca10f47a6b309912d6d9433f8 = echarts.init(
#                     document.getElementById('85500dfca10f47a6b309912d6d9433f8'), 'white', {renderer: 'canvas'});
#                 var option_85500dfca10f47a6b309912d6d9433f8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
# ...

# %%
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data = [123, 153, 89, 107, 98, 23]

list(i) for i in zip(cate, data)
# Out:
# <generator object <genexpr> at 0x104093d58>

# %%
cate = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
data = [123, 153, 89, 107, 98, 23]

# %%
pie = (
    Pie()
    .add('',[list(z) for z in zip(cate, data)]))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dc6778933c6541c189827cd7ff4d63f2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dc6778933c6541c189827cd7ff4d63f2 = echarts.init(
#                     document.getElementById('dc6778933c6541c189827cd7ff4d63f2'), 'white', {renderer: 'canvas'});
#                 var option_dc6778933c6541c189827cd7ff4d63f2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
cate = ['访问', '注册', '加入购物车', '提交订单', '付款成功']
data = [30398, 15230, 10045, 3109, 1698]

funnel = (
        Funnel()
        .add('',[list(z) for z in zip(cate, data)]))
funnel.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="283de4fbcb0d44b9bd47695edb28e965" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_283de4fbcb0d44b9bd47695edb28e965 = echarts.init(
#                     document.getElementById('283de4fbcb0d44b9bd47695edb28e965'), 'white', {renderer: 'canvas'});
#                 var option_283de4fbcb0d44b9bd47695edb28e965 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge

c = (
    Gauge()
    .add("", [("完成率", 66.6)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
    .render("gauge_base.html")
)

# %%
liquid = (Liquid()
          .add("", [0.52, 0.44])
          )

liquid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="9ee3e05520e4457e82f1bfcd1fd0aeb1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_9ee3e05520e4457e82f1bfcd1fd0aeb1 = echarts.init(
#                     document.getElementById('9ee3e05520e4457e82f1bfcd1fd0aeb1'), 'white', {renderer: 'canvas'});
#                 var option_9ee3e05520e4457e82f1bfcd1fd0aeb1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %%
import math
import datetime 

# 虚假数据
begin = datetime.date(2019, 1, 1)
end = datetime.date(2019, 12, 31)
data = [[str(begin + datetime.timedelta(days=i)), abs(math.cos(i/100))* np.random.randint(1000, 1200)]
        for i in range((end - begin).days + 1)]
        
calendar = (
        Calendar()
        .add("", data, calendar_opts=opts.CalendarOpts(range_="2019"))
    )

calendar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dea7b17f6d324a54a50e8bc3e35ab6e1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dea7b17f6d324a54a50e8bc3e35ab6e1 = echarts.init(
#                     document.getElementById('dea7b17f6d324a54a50e8bc3e35ab6e1'), 'white', {renderer: 'canvas'});
#                 var option_dea7b17f6d324a54a50e8bc3e35ab6e1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
import pandas as pd
help (pd.datetime)
# Out:
# Help on class __DatetimeSub in module pandas:
#
# class __DatetimeSub(builtins.object)
#  |  Methods defined here:
#  |
#  |  emit_warning(dummy=0)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(cls, *args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
# /Users/shawnhua/.pyenv/versions/3.6.3/lib/python3.6/inspect.py:441: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   srch_obj = srch_cls.__getattr__(cls, name)
# ...

# %%
data = [
    [78, 91, 123, 78, 82, 67],
    
]


radar = (Radar()
         .add_schema(schema=[
             opts.RadarIndicatorItem(name="语文", max_=150),
             opts.RadarIndicatorItem(name="数学", max_=150),
             opts.RadarIndicatorItem(name="英语", max_=150),
             opts.RadarIndicatorItem(name="物理", max_=100),
             opts.RadarIndicatorItem(name="生物", max_=100),
             opts.RadarIndicatorItem(name="化学", max_=100),
         ]
)
    .add('', data)
)
radar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c35ce3900e6d466a883cf78278c9313d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c35ce3900e6d466a883cf78278c9313d = echarts.init(
#                     document.getElementById('c35ce3900e6d466a883cf78278c9313d'), 'white', {renderer: 'canvas'});
#                 var option_c35ce3900e6d466a883cf78278c9313d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
radar = (
    Radar()
    .add_schema(schema=[
        opts.RadarIndicatorItem(name='语文'，max=150),
        opts.RadatIndicatotItem(name='数学'，max=150),
        opts.RadatIndicatotItem(name='外语'，max=150),
        opts.RadatIndicatotItem(name='物理'，max=150),
        opts.RadatIndicatotItem(name='化学'，max=150),
        opts.RadatIndicatotItem(name='生物'，max=150),
    ])
    .add('',data))
rader.render_notebook()
# Out:
#   File "<ipython-input-262-89b94e07cae3>", line 4
#     opts.RadarIndicatorItem(name='语文'，max=150),
#                                         ^
# SyntaxError: invalid character in identifier

# %%
data = [
    {'name':'湖南',
    'children':[
        {'name':'长沙',
        'children':[
            {'name':'雨花区','value':55},
            {'name':"岳麓区", "value": 34},
            {"name": "天心区", "value": 144},
        ]},
        {'name':'常德',
        'children':[
            {"name": "武陵区", "value": 156},
            {"name": "鼎城区", "value": 134},
        ]},
        ],
    }
        
]
sunburst = (
    Sunburst()
    .add('',data_pair=data))
sunburst.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a6cffc6a204c42fea540fac34aae0771" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a6cffc6a204c42fea540fac34aae0771 = echarts.init(
#                     document.getElementById('a6cffc6a204c42fea540fac34aae0771'), 'white', {renderer: 'canvas'});
#                 var option_a6cffc6a204c42fea540fac34aae0771 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
words = [
    ("hey", 230),
    ("jude", 124),
    ("dont", 436),
    ("make", 255),
    ("it", 247),
    ("bad", 244),
    ("Take", 138),
    ("a sad song", 184),
    ("and", 12),
    ("make", 165),
    ("it", 247),
    ("better", 182),
    ("remember", 255),
    ("to", 150),
    ("let", 162),
    ("her", 266),
    ("into", 60),
    ("your", 82),
    ("heart", 173),
    ("then", 365),
    ("you", 360),
    ("can", 282),
    ("start", 273),
    ("make", 265),
]


wc = (
    WordCloud()
    .add('',words))
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="3620b60488c94c6eb3650c0f60f5db1f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_3620b60488c94c6eb3650c0f60f5db1f = echarts.init(
#                     document.getElementById('3620b60488c94c6eb3650c0f60f5db1f'), 'white', {renderer: 'canvas'});
#                 var option_3620b60488c94c6eb3650c0f60f5db1f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %%
data = [(np.random.randint(0, 100), np.random.randint(0, 100), np.random.randint(0, 100)) for _ in range(100)]

scatter3D = (Scatter3D()
             .add("", data)
             )

scatter3D.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="4dfe79ed24af41c997c71f3d18df6818" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_4dfe79ed24af41c997c71f3d18df6818 = echarts.init(
#                     document.getElementById('4dfe79ed24af41c997c71f3d18df6818'), 'white', {renderer: 'canvas'});
#                 var option_4dfe79ed24af41c997c71f3d18df6818 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %%
data = []
for t in range(0, 1000):
    x = math.cos(t/10)
    y = math.sin(t/10)
    z = t/10
    data.append([x, y, z])

line3D = (Line3D()
          .add("", data,
               xaxis3d_opts=opts.Axis3DOpts(type_="value"),
               yaxis3d_opts=opts.Axis3DOpts(type_="value"))
          )

line3D.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="afd7afb9cb9543b5a2f23360d67b9643" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_afd7afb9cb9543b5a2f23360d67b9643 = echarts.init(
#                     document.getElementById('afd7afb9cb9543b5a2f23360d67b9643'), 'white', {renderer: 'canvas'});
#                 var option_afd7afb9cb9543b5a2f23360d67b9643 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %%
data = [[i, j, np.random.randint(0, 100)] for i in range(24) for j in range(7)]
hour_list = [str(i) for i in range(24)]
week_list = ['周日', '周一', '周二', '周三', '周四', '周五', '周六']


bar3D = (
    Bar3D()
    .add(
        "",
        data,
        xaxis3d_opts=opts.Axis3DOpts(hour_list, type_="category"),
        yaxis3d_opts=opts.Axis3DOpts(week_list, type_="category"),
        zaxis3d_opts=opts.Axis3DOpts(type_="value"),
    )
)

bar3D.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min'
#         }
#     });
# </script>
#
#         <div id="c2c7568972b84b75af5d0e75db087e41" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-gl'], function(echarts) {
#                 var chart_c2c7568972b84b75af5d0e75db087e41 = echarts.init(
#                     document.getElementById('c2c7568972b84b75af5d0e75db087e41'), 'white', {renderer: 'canvas'});
#                 var option_c2c7568972b84b75af5d0e75db087e41 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %%
province = [
    '广东',
    '湖北',
    '湖南',
    '四川',
    '重庆',
    '黑龙江',
    '浙江',
    '山西',
    '河北',
    '安徽',
    '河南',
    '山东',
    '西藏']
data = [(i, np.random.randint(50, 150)) for i in province]

map3d = (
    Geo()
    .add_schema(maptype='china')
    .add('',data)
)
map3d.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="070fe717882242f2ac4020fa640d23fa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_070fe717882242f2ac4020fa640d23fa = echarts.init(
#                     document.getElementById('070fe717882242f2ac4020fa640d23fa'), 'white', {renderer: 'canvas'});
#                 var option_070fe717882242f2ac4020fa640d23fa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
province = [
    '广东',
    '湖北',
    '湖南',
    '四川',
    '重庆',
    '黑龙江',
    '浙江',
    '山西',
    '河北',
    '安徽',
    '河南',
    '山东',
    '西藏']
data = [(i, np.random.randint(50, 150)) for i in province]

map_ = (
    Map()
    .add("", data, 'china')
)
map_.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="2535ed8fb6db4b3cb5bd9f01705851f5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_2535ed8fb6db4b3cb5bd9f01705851f5 = echarts.init(
#                     document.getElementById('2535ed8fb6db4b3cb5bd9f01705851f5'), 'white', {renderer: 'canvas'});
#                 var option_2535ed8fb6db4b3cb5bd9f01705851f5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
from pyecharts.faker import POPULATION


mapglobe = (
    MapGlobe()
    .add_schema()
    .add(
        series_name="",
        maptype="world",
        data_pair=POPULATION[1:]
    )
)

mapglobe.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-gl':'https://assets.pyecharts.org/assets/echarts-gl.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#     <div id="c3db172c950a4087bd7e7e8953b9c62d" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-gl', 'china', 'world'], function(echarts) {
# 		var canvas_c3db172c950a4087bd7e7e8953b9c62d = document.createElement('canvas');
#         var mapChart_c3db172c950a4087bd7e7e8953b9c62d = echarts.init(
# 	    canvas_c3db172c950a4087bd7e7e8953b9c62d, 'white', {width: 4096, height: 2048, renderer: 'canvas'});
#         var mapOption_c3db172c950a4087bd7e7e8953b9c62d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
# ...

# %%
end = datetime.date(2021,4,30)
begin = datetime.date(2021,4,1)
cate = ['Apple', 'Huawei', 'MI', 'Oppo', 'Vivo', 'Samsung']
def random_data(n): return [np.random.randint(100, 200) for i in range(n)]
tl = Timeline()
tl.add_schema()

for i in range((end - begin).days + 1):
    day = begin +datetime.timedelta(days=i)
    
    bar = (
        Bar()
        .add_xaxis(cate)
        .add_yaxis('电商渠道',random_data(len(cate))))
    
    tl.add(bar, day)
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2ff160b7ed064dc39edba77598a811c3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2ff160b7ed064dc39edba77598a811c3 = echarts.init(
#                     document.getElementById('2ff160b7ed064dc39edba77598a811c3'), 'white', {renderer: 'canvas'});
#                 var option_2ff160b7ed064dc39edba77598a811c3 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u7535\u5546\u6e20\u9053",
#                 "legendHoverLink": true,
#                 "data": [
#                     177,
#                     178,
#                     143,
#                     177,
#                     139,
#                     105
#                 ],
# ...

# %%
help (datetime.timedelta())
# Out:
# Help on timedelta object:
#
# class timedelta(builtins.object)
#  |  Difference between two datetime values.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mod__(self, value, /)
#  |      Return self%value.
#  |
# ...

# %%
begin = datetime.date(2020, 4, 1)
end = datetime.date(2020, 4, 20)
date_list = [str(begin + datetime.timedelta(days=i))
             for i in range((end - begin).days + 1)]
date_list
# Out:
# ['2020-04-01',
#  '2020-04-02',
#  '2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20']

# %%
cate = ['Apple', 'Huawei', 'MI', 'Oppo', 'Vivo', 'Samsung']

begin = datetime.date(2020, 4, 1)
end = datetime.date(2020, 4, 20)
date_list = [str(begin + datetime.timedelta(days=i))
             for i in range((end - begin).days + 1)]

def random_data(n): return [np.random.randint(0, 100) for i in range(n)]

tab = Tab()

for c in cate:
    day = begin + datetime.timedelta(days=i)
    
    sca = (EffectScatter()
            .add_xaxis(date_list)
            .add_yaxis('', random_data(len(date_list)))
            )
    tab.add(sca, c)
tab.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
#             padding: 6px 12px;
#             border-top: none;
#         }
#     </style>
# <div class="tab">
# ...

# %%
x_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data = [123, 153, 89, 107, 98, 23]


bar = (Bar()
       .add_xaxis(x_data)
       .add_yaxis('', y_data)
       )

line = (Line()
        .add_xaxis(x_data)
        .add_yaxis('', y_data)
        )

grid = (
    Grid()
    .add(bar,grid_opts=opts.GridOpts(pos_bottom='70%',pos_left='70%'))
    .add(line,grid_opts=opts.GridOpts(pos_left='10%',pos_bottom='10%')))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="82446b90a1574fd6a3441ca4e1d4e706" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_82446b90a1574fd6a3441ca4e1d4e706 = echarts.init(
#                     document.getElementById('82446b90a1574fd6a3441ca4e1d4e706'), 'white', {renderer: 'canvas'});
#                 var option_82446b90a1574fd6a3441ca4e1d4e706 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Bar 
from pyecharts import options as opts
from pyecharts.globals import ThemeType
y_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data_1 = [123, 153, 89, 107, 98, 23]
y_data_2 = [231, 321, 135, 341, 245, 167]

bar = (
        Bar(init_opts=opts.InitOpts(width='600px',height='400px',page_title='AwesomeTag'))
        .add_xaxis(x_data)
        .add_yaxis('baidu',y_data_1)
        .add_yaxis('alibaba',y_data_2)
        .set_global_opts(title_opts=opts.TitleOpts(title='',subtitle='',title_textstyle_opts=opts.TextstyleOpts))
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f085735fcc5641f681db9b5b832adc33" style="width:600px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f085735fcc5641f681db9b5b832adc33 = echarts.init(
#                     document.getElementById('f085735fcc5641f681db9b5b832adc33'), 'light', {renderer: 'canvas'});
#                 var option_f085735fcc5641f681db9b5b832adc33 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "baidu",
#             "legendHoverLink": true,
# ...
